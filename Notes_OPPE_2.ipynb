# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohd-Talha0/MLP/blob/main/Notes_OPPE_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Objectives
#
# *  Learn how to load data from a link provided for the dataset.
# *  How to separate the data into X and y format.
# * How to put conditions on the data to display certain outputs.

# %%
import pandas as pd

# %%
from sklearn.datasets import load_diabetes
diabetes = load_diabetes(as_frame = True)
df = diabetes['data']

# %%
df.loc[4, ['age', 'sex']]
# Out:
# age    0.005383
# sex   -0.044642
# Name: 4, dtype: float64

# %%
df.iloc[4, 0:2]
# Out:
# age    0.005383
# sex   -0.044642
# Name: 4, dtype: float64

# %%
age_df_temp = df.loc[df.age < 0.00538]
age_df_temp.shape
# Out:
# (214, 10)

# %%
age_df_temp
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 5   -0.092695 -0.044642 -0.040696 -0.019442 -0.068991 -0.079288  0.041277
# 6   -0.045472  0.050680 -0.047163 -0.015999 -0.040096 -0.024800  0.000779
# 9   -0.070900 -0.044642  0.039062 -0.033213 -0.012577 -0.034508 -0.024993
# ..        ...       ...       ...       ...       ...       ...       ...
# 435 -0.012780 -0.044642 -0.023451 -0.040099 -0.016704  0.004636 -0.017629
# 436 -0.056370 -0.044642 -0.074108 -0.050427 -0.024960 -0.047034  0.092820
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 1   -0.039493 -0.068332 -0.092204
# ...

# %%
import numpy as np
df = pd.DataFrame(np.random.rand(100, 4), index = range(100), columns = list("ABCD"))
df.shape
# Out:
# (100, 4)

# %% [markdown]
# #Lambda function

# %%
selector = lambda df: df['A'] > 0.5

# %%
df_cut = df.loc[selector]
df_cut.shape
# Out:
# (54, 4)

# %%
selector = lambda df: (df['A'] > 0.5)&(df['B'] < 0.2)
# we can also use 'or'(|) or 'not'(~) conditions

# %%
df_2 = df.loc[selector]
df_2.shape
# Out:
# (16, 4)

# %% [markdown]
# ## Adding a column in the dataframe

# %%
df['E'] = df['A']*100
df.head()
# Out:
#           A         B         C         D          E
# 0  0.334326  0.748265  0.302477  0.905061  33.432644
# 1  0.430447  0.148147  0.890438  0.427275  43.044698
# 2  0.593830  0.501761  0.795027  0.896293  59.382996
# 3  0.397375  0.188935  0.229191  0.381505  39.737473
# 4  0.335086  0.755943  0.049037  0.582895  33.508615

# %%
criteria = df['A'] < 0.2
df.loc[criteria, 'A'] = 0
cr2 = df['A'] == 0
df.loc[cr2]
# Out:
#       A         B         C         D          E
# 27  0.0  0.260651  0.359783  0.918039  19.960257
# 32  0.0  0.287918  0.770918  0.780657  13.286333
# 34  0.0  0.043659  0.700579  0.679443   2.150028
# 44  0.0  0.990375  0.043045  0.899270  15.733093
# 53  0.0  0.279108  0.757800  0.429430   8.922271
# 57  0.0  0.706921  0.760175  0.990639   3.859413
# 69  0.0  0.575334  0.591243  0.296181  16.309738
# 71  0.0  0.394313  0.630674  0.362934  17.216137
# 83  0.0  0.400127  0.606648  0.063150  12.241293
# 90  0.0  0.464601  0.078575  0.419285  15.494047
# 94  0.0  0.529052  0.036379  0.007745   1.259540
# 99  0.0  0.372245  0.748965  0.529825  14.483862

# %%
df.loc[df.E < 34, 'E'] = 0.0
df
# Out:
#            A         B         C         D          E
# 0   0.334326  0.748265  0.302477  0.905061        0.0
# 1   0.430447  0.148147  0.890438  0.427275  43.044698
# 2   0.593830  0.501761  0.795027  0.896293  59.382996
# 3   0.397375  0.188935  0.229191  0.381505  39.737473
# 4   0.335086  0.755943  0.049037  0.582895        0.0
# ..       ...       ...       ...       ...        ...
# 95  0.296690  0.430835  0.733748  0.855731        0.0
# 96  0.743787  0.105366  0.261458  0.714171    74.3787
# 97  0.640031  0.525973  0.307515  0.854155  64.003064
# 98  0.432307  0.648886  0.967133  0.665029  43.230713
# 99  0.000000  0.372245  0.748965  0.529825        0.0
#
# [100 rows x 5 columns]

# %%
from sklearn.metrics import accuracy_score
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

X,y = load_breast_cancer(return_X_y = True, as_frame = True)

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.25, random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier

model = KNeighborsClassifier()
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 0.965034965034965

# %%
y_pred = model.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.965034965034965

# %%
from sklearn.metrics import ConfusionMatrixDisplay

ConfusionMatrixDisplay.from_estimator(model, X_test, y_test)

# %%
from sklearn.metrics import precision_score
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

precision_score(y_test, y_pred)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.9666666666666667
